# %%
# !cargo run --example line_shape_lorentz lorentz_width_test.csv 0.04
# Out:
#    Compiling diatomic_simulator v0.1.0 (/home/aki/diatomic_simulator)
#     Finished ]8;;https://doc.rust-lang.org/cargo/reference/profiles.html#default-profiles\`dev` profile [unoptimized + debuginfo]]8;;\ target(s) in 0.15s
#      Running `target/debug/examples/line_shape_lorentz lorentz_width_test.csv 0.04`

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_csv = pd.read_csv("lorentz_width_test.csv", header = None, names = ["x", "y"])
data_x, data_y = df_csv["x"], df_csv["y"]

plt.plot(data_x, data_y)
plt.show()

# %%
# !cargo run --example line_shape_lorentz_2 lorentz_width_test_2.csv 0.04
# Out:
#    Compiling diatomic_simulator v0.1.0 (/home/aki/diatomic_simulator)
#     Finished ]8;;https://doc.rust-lang.org/cargo/reference/profiles.html#default-profiles\`dev` profile [unoptimized + debuginfo]]8;;\ target(s) in 0.24s
#      Running `target/debug/examples/line_shape_lorentz_2 lorentz_width_test_2.csv 0.04`

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_csv = pd.read_csv("lorentz_width_test_2.csv", header = None, names = ["x", "y"])
data_x, data_y = df_csv["x"], df_csv["y"]

plt.plot(data_x, data_y)
plt.show()
